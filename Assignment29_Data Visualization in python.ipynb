# %%
import numpy as np
import pandas as pd
path = 'C:/Users/Abdullah Rashid/Desktop/Data Analysis with Python Udemy Course/Pandas+Course+Resources/Pandas Course Resources/retail/oil.csv'
oil = pd.read_csv(path)
oil.columns = ['date','price']
oil
# Out:
#             date  price
# 0     2013-01-01    NaN
# 1     2013-01-02  93.14
# 2     2013-01-03  92.97
# 3     2013-01-04  93.12
# 4     2013-01-07  93.20
# ...          ...    ...
# 1213  2017-08-25  47.65
# 1214  2017-08-28  46.40
# 1215  2017-08-29  46.46
# 1216  2017-08-30  45.96
# 1217  2017-08-31  47.26
#
# [1218 rows x 2 columns]

# %%
oil.astype({'date':'datetime64'}).set_index('date').loc['2013':'2017'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
import seaborn as sns
sns.set_style("darkgrid")   # darkgrid style is required by company
oil.astype({'date':'datetime64'}).set_index('date').loc['2013':'2017'].plot(title = "Oil Prices 2013 to 2017",
                                                                            xlabel = 'Year',
                                                                            ylabel= 'Price in US$',
                                                                            color = 'Black' # can also use c = 'Black',
                                                                            legend = True)
# Out:
# <AxesSubplot:title={'center':'Oil Prices 2013 to 2017'}, xlabel='Year', ylabel='Price in US$'>
