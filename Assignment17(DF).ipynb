# %%
import pandas as pd
import numpy as np
path = "C:/Users/Abdullah Rashid/Desktop/Data Analysis with Python Udemy Course/Pandas+Course+Resources/Pandas Course Resources/retail/transactions.csv"
transactions = pd.read_csv(path)
transactions.drop([0],inplace = True,axis = 0) # first row is removed and changes are saved permanently
transactions
# Out:
#              date  store_nbr  transactions
# 1      2013-01-02          1          2111
# 2      2013-01-02          2          2358
# 3      2013-01-02          3          3487
# 4      2013-01-02          4          1922
# 5      2013-01-02          5          1903
# ...           ...        ...           ...
# 83483  2017-08-15         50          2804
# 83484  2017-08-15         51          1573
# 83485  2017-08-15         52          2255
# 83486  2017-08-15         53           932
# 83487  2017-08-15         54           802
#
# [83487 rows x 3 columns]

# %%
transactions1 = transactions.drop('date',axis=1) # date column is removed but not in place
transactions1
# Out:
#        store_nbr  transactions
# 1              1          2111
# 2              2          2358
# 3              3          3487
# 4              4          1922
# 5              5          1903
# ...          ...           ...
# 83483         50          2804
# 83484         51          1573
# 83485         52          2255
# 83486         53           932
# 83487         54           802
#
# [83487 rows x 2 columns]

# %%
transaction2 = transactions.drop_duplicates('store_nbr',keep = 'last',ignore_index = True) # subset = 'store_nbr' will also give same result
transaction2 # last transactions of each store
# Out:
#           date  store_nbr  transactions
# 0   2017-08-15          1          1693
# 1   2017-08-15          2          1737
# 2   2017-08-15          3          2956
# 3   2017-08-15          4          1283
# 4   2017-08-15          5          1310
# 5   2017-08-15          6          1589
# 6   2017-08-15          7          1780
# 7   2017-08-15          8          2621
# 8   2017-08-15          9          2155
# 9   2017-08-15         10          1010
# 10  2017-08-15         11          2360
# 11  2017-08-15         12          1096
# 12  2017-08-15         13           842
# 13  2017-08-15         14          1241
# 14  2017-08-15         15          1320
# 15  2017-08-15         16           742
# 16  2017-08-15         17          1504
# 17  2017-08-15         18          1343
# 18  2017-08-15         19          1158
# 19  2017-08-15         20          1516
# 20  2017-08-15         21          1059
# 21  2017-08-15         22           766
# ...
